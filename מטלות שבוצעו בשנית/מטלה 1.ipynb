# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url)

# %% [markdown]
# #### ex 1: קיראו את קובץ החיסונים שקראנו בכיתה (ראו שיעור 2) והציגו את 5 השורות הראשונות בקובץ.

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# #### ex 2: ביחרו מדינה שמתחילה באותה האות כמו השם של אחד מחברי הצוות, באנגלית. הראו בקוד כיצד אתם מוצאים את המדינה. רמז: כדי למצוא מדינות כאלו ניתן להשתמש בפקודה
# 'str.contains'

# %%
vacc_df[vacc_df['location'].str.startswith('S')]
# Out:
#            location iso_code        date  total_vaccinations  \
# 19839  Saint Helena      SHN  2021-02-03               107.0
# 19840  Saint Helena      SHN  2021-02-04                 NaN
# 19841  Saint Helena      SHN  2021-02-05                 NaN
# 19842  Saint Helena      SHN  2021-02-06                 NaN
# 19843  Saint Helena      SHN  2021-02-07                 NaN
# ...             ...      ...         ...                 ...
# 23309         Syria      SYR  2021-06-02                 NaN
# 23310         Syria      SYR  2021-06-03                 NaN
# 23311         Syria      SYR  2021-06-04                 NaN
# 23312         Syria      SYR  2021-06-05                 NaN
# 23313         Syria      SYR  2021-06-06             71519.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 19839              107.0                      NaN                     NaN
# 19840                NaN                      NaN                     NaN
# ...

# %%
s_data= vacc_df[vacc_df['location']=='Saint Helena'].copy()
s_data.head()
# Out:
#            location iso_code        date  total_vaccinations  \
# 19839  Saint Helena      SHN  2021-02-03               107.0
# 19840  Saint Helena      SHN  2021-02-04                 NaN
# 19841  Saint Helena      SHN  2021-02-05                 NaN
# 19842  Saint Helena      SHN  2021-02-06                 NaN
# 19843  Saint Helena      SHN  2021-02-07                 NaN
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 19839              107.0                      NaN                     NaN
# 19840                NaN                      NaN                     NaN
# 19841                NaN                      NaN                     NaN
# 19842                NaN                      NaN                     NaN
# 19843                NaN                      NaN                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 19839                 NaN                            1.76
# ...

# %% [markdown]
# #### ex 3:  כמה רשומות יש עבור המדינה שבחרתם?

# %%
len(s_data)
s_data.shape[0]
# Out:
# 92

# %% [markdown]
# #### ex 4: באיזה תאריך התחסנו הכי הרבה אנשים במדינה שבחרתם?

# %%
s_data.daily_vaccinations.max()
s
# Out:
# 7892.0

# %%
s_data_date=s_data[s_data.loc[:,'daily_vaccinations'] == s_data.daily_vaccinations.max()]
s_data_date
# Out:
#            location iso_code        date  total_vaccinations  \
# 19889  Saint Helena      SHN  2021-03-25              4454.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 19889             4344.0                    110.0                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 19889               165.0                           73.37
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 19889                          71.55                                 1.81
#
#        daily_vaccinations_per_million
# 19889                         27178.0

# %%
s_data[s_data.daily_vaccinations==s_data.daily_vaccinations.max()]
# Out:
#            location iso_code        date  total_vaccinations  \
# 19889  Saint Helena      SHN  2021-03-25              4454.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 19889             4344.0                    110.0                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 19889               165.0                           73.37
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 19889                          71.55                                 1.81
#
#        daily_vaccinations_per_million
# 19889                         27178.0

# %%
s_data_date.date
# Out:
# 19889    2021-03-25
# Name: date, dtype: object

# %% [markdown]
# #### ex 5: הציגו את 3 הרשומות (שורות) הראשונות עבור המדינה שבחרתם, עם העמודות של התאריך ומספר המתחסנים היומי ושם המדינה בלבד (כלומר הציגו שלוש שורות ושלוש עמודות)

# %%
s_data[['location','date','daily_vaccinations']].head(3)
# Out:
#            location        date  daily_vaccinations
# 19839  Saint Helena  2021-02-03                 NaN
# 19840  Saint Helena  2021-02-04                75.0
# 19841  Saint Helena  2021-02-05                75.0

# %% [markdown]
# ### ex:6 מה הוא מספר המתחסנים הממוצע מידי יום במדינה שבחרתם?. יש לחשב ממוצע על פני כל הימים החל מהתאריך בו החלו לחסן במדינה שבחרתם עבור העמודה daily_vaccinations

# %%
s_data['daily_vaccinations'].mean()
# Out:
# 84.81318681318682

# %% [markdown]
# ### ex 7:  people_vaccinated_per_hundredהציגו רק את הימים עם נתונים (הורידו ימים ללא נתונים אם ישנם ימים כאלו) עבור המדינה שבחרתם עבור העמודה:

# %%
s_data_withoutNAN= s_data.dropna(subset = ['people_vaccinated_per_hundred'])
s_data_withoutNAN
# Out:
#            location iso_code        date  total_vaccinations  \
# 19839  Saint Helena      SHN  2021-02-03               107.0
# 19879  Saint Helena      SHN  2021-03-15              3107.0
# 19882  Saint Helena      SHN  2021-03-18              3300.0
# 19889  Saint Helena      SHN  2021-03-25              4454.0
# 19904  Saint Helena      SHN  2021-04-09              5373.0
# 19930  Saint Helena      SHN  2021-05-05              7892.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 19839              107.0                      NaN                     NaN
# 19879             3107.0                      NaN                     NaN
# 19882             3300.0                      NaN                     NaN
# 19889             4344.0                    110.0                     NaN
# 19904             4361.0                   1012.0                     NaN
# 19930             4361.0                   3531.0                     NaN
#
# ...

# %% [markdown]
# ### ex 8: מהו מספר המתחסנים הממוצע ל100 איש במדינה שבחרתם? יש לחשב ממוצע על פני כל הימים החל מהתאריך בו החלו לחסן במדינה שבחרתם. שימו לב היטב לסוג הממוצע שנדרש לחשב כאן. כמו כן דאגו להוריד את הימים בהם אין נתונים לפני שאתם מבצעים את החישוב

# %%
from scipy import stats
stats.hmean(s_data_withoutNAN.loc[:,'people_vaccinated_per_hundred'])
# Out:
# 9.260168989507786

# %% [markdown]
# ### ex 9:  מה גדול יותר, הממוצע או החציון של מספר המתחסנים היומי על פני כל ימי החיסון החל מהתאריך בו החלו לחסן במדינה בחרתם? הסבירו מדוע אתם חושבים שזה כך. הכוונה לעמודה daily_vaccinations

# %%
s_data.daily_vaccinations.mean()
# Out:
# 84.81318681318682

# %%
s_data.daily_vaccinations.median()
# Out:
# 75.0
